# %% [markdown]
# ## Importing necessary libraries and data

# %%
import numpy as np   
from sklearn.linear_model import LinearRegression
import pandas as pd    
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns
from sklearn.model_selection import train_test_split # Sklearn package's randomized data splitting function

# %% [markdown]
# # Problem Summary

# %% [markdown]
# The rising potential of this comparatively under-the-radar market fuels the need for an ML-based solution to develop a dynamic pricing strategy for used and refurbished smartphones. ReCell, a startup aiming to tap the potential in this market, has hired you as a data scientist. They want you to analyze the data provided and build a linear regression model to predict the price of a used phone and identify factors that significantly influence it.

# %% [markdown]
# # Data Set Overview

# %% [markdown]
# The data contains the different attributes of used/refurbished phones. The detailed data dictionary is given below.

# %% [markdown]
#  brand_name: Name of manufacturing brand\
# os: OS on which the phone runs\
# screen_size: Size of the screen in cm\
# 4g: Whether 4G is available or not\
# 5g: Whether 5G is available or not\
# main_camera_mp: Resolution of the rear camera in megapixels\
# selfie_camera_mp: Resolution of the front camera in megapixels\
# int_memory: Amount of internal memory (ROM) in GB\
# ram: Amount of RAM in GB\
# battery: Energy capacity of the phone battery in mAh\
# weight: Weight of the phone in grams\
# release_year: Year when the phone model was released\
# days_used: Number of days the used/refurbished phone has been used\
# new_price: Price of a new phone of the same model in euros\
# used_price: Price of the used/refurbished phone in euros\

# %% [markdown]
# # Reading Data and Data Overview

# %% [markdown]
# The dataset has 3571 rows with 15 columns with 4 categorical column and 11 numerical columns.

# %%
df = pd.read_csv("used_phone_data.csv")  
df.shape
# Out:
# (3571, 15)

# %%
df.dtypes
# Out:
# brand_name           object
# os                   object
# screen_size         float64
# 4g                   object
# 5g                   object
# main_camera_mp      float64
# selfie_camera_mp    float64
# int_memory          float64
# ram                 float64
# battery             float64
# weight              float64
# release_year          int64
# days_used             int64
# new_price           float64
# used_price          float64
# dtype: object

# %%
df.head(10)
# Out:
#   brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0      Honor  Android        23.97  yes   no            13.0
# 1      Honor  Android        28.10  yes  yes            13.0
# 2      Honor  Android        24.29  yes  yes            13.0
# 3      Honor  Android        26.04  yes  yes            13.0
# 4      Honor  Android        15.72  yes   no            13.0
# 5      Honor  Android        21.43  yes   no            13.0
# 6      Honor  Android        19.84  yes   no             8.0
# 7      Honor  Android        18.57  yes   no            13.0
# 8      Honor  Android        15.72  yes   no            13.0
# 9      Honor  Android        21.43  yes   no            13.0
#
#    selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0               5.0        64.0  3.0   3020.0   146.0          2020
# 1              16.0       128.0  8.0   4300.0   213.0          2020
# 2               8.0       128.0  8.0   4200.0   213.0          2020
# 3               8.0        64.0  6.0   7250.0   480.0          2020
# 4               8.0        64.0  3.0   5000.0   185.0          2020
# 5               8.0        64.0  4.0   4000.0   176.0          2020
# 6               5.0        32.0  2.0   3020.0   144.0          2020
# 7               8.0        64.0  4.0   3400.0   164.0          2020
# 8              16.0       128.0  6.0   4000.0   165.0          2020
# 9               8.0       128.0  6.0   4000.0   176.0          2020
#
#    days_used  new_price  used_price
# 0        127     111.62       86.96
# 1        325     249.39      161.49
# 2        162     359.47      268.55
# 3        345     278.93      180.23
# 4        293     140.87      103.80
# 5        223     157.70      113.67
# 6        234      91.74       72.29
# 7        219     179.24      132.91
# 8        161     200.32      150.88
# 9        327     159.75      103.59

# %%
df.isnull().sum()
# Out:
# brand_name            0
# os                    0
# screen_size           0
# 4g                    0
# 5g                    0
# main_camera_mp      180
# selfie_camera_mp      2
# int_memory           10
# ram                  10
# battery               6
# weight                7
# release_year          0
# days_used             0
# new_price             0
# used_price            0
# dtype: int64

# %% [markdown]
# Box Plot on the Used_price column which will be prediction column . It is evident that there are some outliers on theused_price column

# %%
fig, ax = plt.subplots(figsize=(8, 5))
boxplot = df.boxplot(column=['used_price'],grid=False, rot=45, fontsize=15)

# %%
fig, ax = plt.subplots(figsize=(8, 5))
boxplot = df.boxplot(column=['screen_size', 'main_camera_mp','selfie_camera_mp'],grid=False, rot=45, fontsize=15)

# %% [markdown]
# The outliers might be affected for the other columns also. this has to be investigated later in the notebook

# %%
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(8, 7),
                        tight_layout = True)
 
axs.hist(df.screen_size, bins = 5)
 
# Show plot
plt.show()

# %%
df.brand_name.value_counts().plot(kind='barh',figsize =(18, 12))

# %% [markdown]
# The brand name others might need to be refilled with possible values

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %% [markdown]
# **Questions**:
#
# 1. What does the distribution of used phone prices look like?
# 2. What percentage of the used phone market is dominated by Android devices?
# 3. The amount of RAM is important for the smooth functioning of a phone. How does the amount of RAM vary with the brand?
# 4. A large battery often increases a phone's weight, making it feel uncomfortable in the hands. How does the weight vary for phones offering large batteries (more than 4500 mAh)?
# 5. Bigger screens are desirable for entertainment purposes as they offer a better viewing experience. How many phones are available across different brands with a screen size larger than 6 inches?
# 6. Budget phones nowadays offer great selfie cameras, allowing us to capture our favorite moments with loved ones. What is the distribution of budget phones offering greater than 8MP selfie cameras across brands?
# 7. Which attributes are highly correlated with the used phone price?

# %% [markdown]
# ##### 1.What does the distribution of used phone prices look like?

# %% [markdown]
# This is right skewed histogram .  Where the mean is 109 and median as 75 and kode is 59.78. But there are ouliers also which is contributing for the high mean value.

# %%
df['used_price'].describe()
# Out:
# count    3571.000000
# mean      109.880277
# std       121.501226
# min         2.510000
# 25%        45.205000
# 50%        75.530000
# 75%       126.000000
# max      1916.540000
# Name: used_price, dtype: float64

# %%
print('The mode value of the Used Price  :  ',df['used_price'].mode())
# Out:
# The mode value of the Used Price  :   0    59.78
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 6))
boxplot = df.boxplot(column=['used_price'],grid=False, rot=45, fontsize=15)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
boxplot = df.used_price.hist(bins=30)

# %% [markdown]
# ##### 2. What percentage of the used phone market is dominated by Android devices?

# %% [markdown]
# About 90% of market is dominated by the andoriod os and the value of record count 3246

# %%
fig, ax = plt.subplots(figsize=(15, 6))   
width = 0.75 # the width of the bars 
ind = np.arange(len(df.os.value_counts() / len(df.os)))  # the x locations for the groups
ax.barh(ind, df.os.value_counts(), width, color="lightgreen")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(df.os.value_counts().keys(), minor=False)
plt.title('Count of Records/Mobile with respect to OS')
plt.xlabel('Values')
plt.ylabel('OS Name') 
for i, v in enumerate(df['os'].value_counts().keys()):
    str1 = round((df[df.os==v].os.value_counts()/len(df.os))*100,2).astype(str) +"%"
    x =df[df.os==v].os.value_counts()
    ax.text(x + 3, i + .1, str(str1.values), color='blue', fontweight='bold')
    ax.text(x + 3, i + .25, str(x.values), color='blue', fontweight='bold')

# %% [markdown]
# ##### 3. The amount of RAM is important for the smooth functioning of a phone. How does the amount of RAM vary with the brand?

# %% [markdown]
# no relation between the Ram and the brand name.  The scatrerplot doesnt signify any corelation . The most frequent ram is 4 .

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10, 10)) 
plt.title('plot between brand_name and ram')
plt.xlabel('ram')
plt.ylabel('brand Name') 
ax = sns.scatterplot(x="ram",y="brand_name",data=df)

# %% [markdown]
# ##### 4. A large battery often increases a phone's weight, making it feel uncomfortable in the hands. How does the weight vary for phones offering large batteries (more than 4500 mAh)?

# %% [markdown]
# The battery and weight are hightly correlated. the increase inlarge batteries increase the weight also.  After the 4500mAh , the weight is again correlated to battery.

# %%
df[['battery','weight']].corr()
# Out:
#           battery    weight
# battery  1.000000  0.704468
# weight   0.704468  1.000000

# %%
df1=df[(df.battery >=4500)]
df1[['battery','weight']].corr()
# Out:
#           battery    weight
# battery  1.000000  0.724347
# weight   0.724347  1.000000

# %%
fig, ax = plt.subplots(figsize=(8, 6))   
plt.title('relation between Battery and weight where battery')
plt.xlabel('Values')
plt.ylabel('OS Name') 
ax = sns.scatterplot(x="battery",y="weight",data=df1)

# %% [markdown]
# ##### 5. Bigger screens are desirable for entertainment purposes as they offer a better viewing experience. How many phones are available across different brands with a screen size larger than 6 inches?

# %% [markdown]
# There are 1235 phones greater than 6 imch out of 3571 phones. and the Huawei brand most dominant brand with bigger screen size

# %%
df1=df[(df.screen_size >6*2.54)]

# %%
df1.shape
# Out:
# (1235, 15)

# %%
fig, ax = plt.subplots(figsize=(18, 10))   
width = 0.75 # the width of the bars 
ind = np.arange(len(df1.brand_name.value_counts() / len(df.os)))
ax.barh(ind, df1.brand_name.value_counts(), width, color="lightgreen")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(df1.brand_name.value_counts().keys(), minor=False)
plt.title('Count of Records/Mobile having screensize greater then 6 inch ')
plt.xlabel('Values')
plt.ylabel('OS Name') 
for i, v in enumerate(df1['brand_name'].value_counts().keys()):
    x =df1[df1.brand_name==v].brand_name.value_counts()
    ax.text(x + 3, i + .00001, str(x.values), color='blue')

# %% [markdown]
# ##### 6. Budget phones nowadays offer great selfie cameras, allowing us to capture our favorite moments with loved ones. What is the distribution of budget phones offering greater than 8MP selfie cameras across brands?

# %% [markdown]
# not any particular pattern , it is distributed acroos the price, there are other factors also deciding the price

# %%
df1=df[(df.selfie_camera_mp >8)]

# %%
#ax = sns.scatterplot(x="selfie_camera_mp",y="used_price",data=df1)

sns.relplot(
    data=df1, x="selfie_camera_mp", y="used_price",
    hue="brand_name",
    kind="scatter"
)

# %% [markdown]
# #### 7. Which attributes are highly correlated with the used phone price?

# %% [markdown]
# the below columns are positive correlated with used proce. 'int_memory', 'release_year',
#        'selfie_camera_mp', 'ram', '5g', 'new_price'.
#
# Whereas the below colimns are negative co-related with days_used

# %%
df = pd.read_csv("used_phone_data.csv")  
df.shape
# Out:
# (3571, 15)

# %%
df["4g"]=df["4g"].map(dict(yes=1, no=0))
df["5g"]=df["5g"].map(dict(yes=1, no=0))

dummy=pd.get_dummies(df["os"])
df=df.merge(dummy,left_index=True,right_index=True)

dummy=pd.get_dummies(df["brand_name"])
df=df.merge(dummy,left_index=True,right_index=True)

# %%
df1=df

# %%
df_columns = df.drop(['used_price'], axis=1)
df_used_price = df['used_price']

# %%
df["4g"].value_counts()
# Out:
# 1    2359
# 0    1212
# Name: 4g, dtype: int64

# %%
df_corr= df_columns.corrwith(df_used_price)
df_corr.sort_values(inplace=True)
df_corr.index

df_columns.corrwith(df_used_price)

fig, ax = plt.subplots(figsize=(18, 10))  
objects = df_corr.index
y_pos = np.arange(len(objects))
# this does not work 
# correlation = [corr_open, corr_high, corr_low, corr_close, corr_volume]

plt.barh(df_corr.index, df_corr, align='center', alpha=0.5)
plt.ylabel('Correlation', fontsize=11)
plt.yticks(size = 9)
plt.title('Correlations with used_price ', fontsize=12)

plt.show()

# %% [markdown]
# ## Data Preprocessing
#
# - Missing value treatment
# - Feature engineering (if needed)
# - Outlier detection and treatment (if needed)
# - Preparing data for modeling
# - Any other preprocessing steps (if needed)

# %%
df = pd.read_csv("used_phone_data.csv")  
df.shape
# Out:
# (3571, 15)

# %% [markdown]
#  ##### Missing value treatment

# %% [markdown]
# ##### 1) can compute OS based on the brand name

# %%
df.groupby(['brand_name','os']).count()
# Out:
#                     screen_size   4g   5g  main_camera_mp  selfie_camera_mp  \
# brand_name os
# Acer       Android           48   48   48              48                48
#            Others             1    1    1               1                 1
#            Windows            2    2    2               2                 2
# Alcatel    Android          110  110  110             110               110
#            Others            15   15   15              15                15
# Apple      Others             3    3    3               3                 3
#            iOS               56   56   56              56                56
# Asus       Android          126  126  126             122               126
# BlackBerry Android           10   10   10               6                10
#            Others            12   12   12              12                12
# Celkon     Android           22   22   22              22                22
#            Others            15   15   15              15                15
# Coolpad    Android           22   22   22              19                22
# Gionee     Android           56   56   56              56                56
# Google     Android           15   15   15              15                13
# HTC        Android          107  107  107             107               107
#            Windows            3    3    3               3                 3
# Honor      Android          116  116  116             116               116
#            Others             2    2    2               2                 2
# Huawei     Android          255  255  255             255               255
#            Others             7    7    7               7                 7
#            Windows            2    2    2               2                 2
# Infinix    Android           10   10   10               0                10
# Karbonn    Android           30   30   30              30                30
# LG         Android          203  203  203             203               203
#            Others             9    9    9               9                 9
# Lava       Android           35   35   35              33                35
#            Windows            1    1    1               1                 1
# Lenovo     Android          172  172  172             172               172
# Meizu      Android           62   62   62              47                62
# Micromax   Android          107  107  107             107               107
#            Others            11   11   11              11                11
#            Windows            2    2    2               2                 2
# Microsoft  Windows           22   22   22              22                22
# Motorola   Android          110  110  110              92               110
# Nokia      Android           46   46   46              46                46
#            Others            54   54   54              54                54
#            Windows           21   21   21              21                21
# OnePlus    Android           22   22   22               5                22
# Oppo       Android          129  129  129             109               129
# Others     Android          466  466  466             466               466
#            Others            34   34   34              34                34
#            Windows            9    9    9               9                 9
# Panasonic  Android           47   47   47              45                47
# Realme     Android           41   41   41               5                41
# Samsung    Android          325  325  325             325               325
#            Others            36   36   36              36                36
#            Windows            3    3    3               3                 3
# Sony       Android           88   88   88              81                88
# Spice      Android           30   30   30              30                30
# Vivo       Android          117  117  117             103               117
# XOLO       Android           47   47   47              47                47
#            Windows            2    2    2               2                 2
# Xiaomi     Android          132  132  132             109               132
#            Others             2    2    2               1                 2
# ZTE        Android          140  140  140             136               140
#            Others             1    1    1               1                 1
#
#                     int_memory  ram  battery  weight  release_year  days_used  \
# brand_name os
# Acer       Android          48   48       48      48            48         48
#            Others            1    1        1       1             1          1
#            Windows           2    2        2       2             2          2
# Alcatel    Android         110  110      110     110           110        110
#            Others           15   15       15      15            15         15
# Apple      Others            3    3        3       3             3          3
#            iOS              56   56       56      56            56         56
# Asus       Android         126  126      126     126           126        126
# BlackBerry Android          10   10       10      10            10         10
#            Others           12   12       12      12            12         12
# Celkon     Android          22   22       22      22            22         22
#            Others           15   15       15      15            15         15
# Coolpad    Android          22   22       22      22            22         22
# Gionee     Android          56   56       56      56            56         56
# Google     Android          15   15       15      15            15         15
# HTC        Android         107  107      107     107           107        107
#            Windows           3    3        3       3             3          3
# Honor      Android         116  116      116     116           116        116
#            Others            2    2        2       2             2          2
# Huawei     Android         255  255      255     255           255        255
#            Others            7    7        7       7             7          7
#            Windows           2    2        2       2             2          2
# Infinix    Android          10   10       10      10            10         10
# Karbonn    Android          30   30       30      30            30         30
# LG         Android         203  203      203     203           203        203
#            Others            9    9        9       9             9          9
# Lava       Android          35   35       35      35            35         35
#            Windows           1    1        1       1             1          1
# Lenovo     Android         172  172      172     172           172        172
# Meizu      Android          62   62       59      62            62         62
# Micromax   Android         107  107      107     107           107        107
#            Others           11   11       11      11            11         11
#            Windows           2    2        2       2             2          2
# Microsoft  Windows          22   22       21      22            22         22
# Motorola   Android         110  110      110     110           110        110
# Nokia      Android          46   46       46      46            46         46
#            Others           44   44       52      54            54         54
#            Windows          21   21       21      21            21         21
# OnePlus    Android          22   22       22      22            22         22
# Oppo       Android         129  129      129     129           129        129
# Others     Android         466  466      466     466           466        466
#            Others           34   34       34      34            34         34
#            Windows           9    9        9       9             9          9
# Panasonic  Android          47   47       47      47            47         47
# Realme     Android          41   41       41      41            41         41
# Samsung    Android         325  325      325     325           325        325
#            Others           36   36       36      36            36         36
#            Windows           3    3        3       3             3          3
# Sony       Android          88   88       88      88            88         88
# Spice      Android          30   30       30      30            30         30
# Vivo       Android         117  117      117     117           117        117
# XOLO       Android          47   47       47      41            47         47
#            Windows           2    2        2       1             2          2
# Xiaomi     Android         132  132      132     132           132        132
#            Others            2    2        2       2             2          2
# ZTE        Android         140  140      140     140           140        140
#            Others            1    1        1       1             1          1
#
#                     new_price  used_price
# brand_name os
# Acer       Android         48          48
#            Others           1           1
#            Windows          2           2
# Alcatel    Android        110         110
#            Others          15          15
# Apple      Others           3           3
#            iOS             56          56
# Asus       Android        126         126
# BlackBerry Android         10          10
#            Others          12          12
# Celkon     Android         22          22
#            Others          15          15
# Coolpad    Android         22          22
# Gionee     Android         56          56
# Google     Android         15          15
# HTC        Android        107         107
#            Windows          3           3
# Honor      Android        116         116
#            Others           2           2
# Huawei     Android        255         255
#            Others           7           7
#            Windows          2           2
# Infinix    Android         10          10
# Karbonn    Android         30          30
# LG         Android        203         203
#            Others           9           9
# Lava       Android         35          35
#            Windows          1           1
# Lenovo     Android        172         172
# Meizu      Android         62          62
# Micromax   Android        107         107
#            Others          11          11
#            Windows          2           2
# Microsoft  Windows         22          22
# Motorola   Android        110         110
# Nokia      Android         46          46
#            Others          54          54
#            Windows         21          21
# OnePlus    Android         22          22
# Oppo       Android        129         129
# Others     Android        466         466
#            Others          34          34
#            Windows          9           9
# Panasonic  Android         47          47
# Realme     Android         41          41
# Samsung    Android        325         325
#            Others          36          36
#            Windows          3           3
# Sony       Android         88          88
# Spice      Android         30          30
# Vivo       Android        117         117
# XOLO       Android         47          47
#            Windows          2           2
# Xiaomi     Android        132         132
#            Others           2           2
# ZTE        Android        140         140
#            Others           1           1

# %%
df['os'][(df['brand_name'] == 'ZTE' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'Xiaomi' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'Honor' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'Alcatel' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'Celkon' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'BlackBerry' ) &  (df['os'] == 'Others') ]  ='Android'
df['os'][(df['brand_name'] == 'Apple' ) &  (df['os'] == 'Others') ]  ='iOS'
# Out:
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df.groupby(['brand_name','os']).count()
# Out:
#                     screen_size   4g   5g  main_camera_mp  selfie_camera_mp  \
# brand_name os
# Acer       Android           48   48   48              48                48
#            Others             1    1    1               1                 1
#            Windows            2    2    2               2                 2
# Alcatel    Android          125  125  125             125               125
# Apple      iOS               59   59   59              59                59
# Asus       Android          126  126  126             122               126
# BlackBerry Android           22   22   22              18                22
# Celkon     Android           37   37   37              37                37
# Coolpad    Android           22   22   22              19                22
# Gionee     Android           56   56   56              56                56
# Google     Android           15   15   15              15                13
# HTC        Android          107  107  107             107               107
#            Windows            3    3    3               3                 3
# Honor      Android          118  118  118             118               118
# Huawei     Android          255  255  255             255               255
#            Others             7    7    7               7                 7
#            Windows            2    2    2               2                 2
# Infinix    Android           10   10   10               0                10
# Karbonn    Android           30   30   30              30                30
# LG         Android          203  203  203             203               203
#            Others             9    9    9               9                 9
# Lava       Android           35   35   35              33                35
#            Windows            1    1    1               1                 1
# Lenovo     Android          172  172  172             172               172
# Meizu      Android           62   62   62              47                62
# Micromax   Android          107  107  107             107               107
#            Others            11   11   11              11                11
#            Windows            2    2    2               2                 2
# Microsoft  Windows           22   22   22              22                22
# Motorola   Android          110  110  110              92               110
# Nokia      Android           46   46   46              46                46
#            Others            54   54   54              54                54
#            Windows           21   21   21              21                21
# OnePlus    Android           22   22   22               5                22
# Oppo       Android          129  129  129             109               129
# Others     Android          466  466  466             466               466
#            Others            34   34   34              34                34
#            Windows            9    9    9               9                 9
# Panasonic  Android           47   47   47              45                47
# Realme     Android           41   41   41               5                41
# Samsung    Android          325  325  325             325               325
#            Others            36   36   36              36                36
#            Windows            3    3    3               3                 3
# Sony       Android           88   88   88              81                88
# Spice      Android           30   30   30              30                30
# Vivo       Android          117  117  117             103               117
# XOLO       Android           47   47   47              47                47
#            Windows            2    2    2               2                 2
# Xiaomi     Android          134  134  134             110               134
# ZTE        Android          141  141  141             137               141
#
#                     int_memory  ram  battery  weight  release_year  days_used  \
# brand_name os
# Acer       Android          48   48       48      48            48         48
#            Others            1    1        1       1             1          1
#            Windows           2    2        2       2             2          2
# Alcatel    Android         125  125      125     125           125        125
# Apple      iOS              59   59       59      59            59         59
# Asus       Android         126  126      126     126           126        126
# BlackBerry Android          22   22       22      22            22         22
# Celkon     Android          37   37       37      37            37         37
# Coolpad    Android          22   22       22      22            22         22
# Gionee     Android          56   56       56      56            56         56
# Google     Android          15   15       15      15            15         15
# HTC        Android         107  107      107     107           107        107
#            Windows           3    3        3       3             3          3
# Honor      Android         118  118      118     118           118        118
# Huawei     Android         255  255      255     255           255        255
#            Others            7    7        7       7             7          7
#            Windows           2    2        2       2             2          2
# Infinix    Android          10   10       10      10            10         10
# Karbonn    Android          30   30       30      30            30         30
# LG         Android         203  203      203     203           203        203
#            Others            9    9        9       9             9          9
# Lava       Android          35   35       35      35            35         35
#            Windows           1    1        1       1             1          1
# Lenovo     Android         172  172      172     172           172        172
# Meizu      Android          62   62       59      62            62         62
# Micromax   Android         107  107      107     107           107        107
#            Others           11   11       11      11            11         11
#            Windows           2    2        2       2             2          2
# Microsoft  Windows          22   22       21      22            22         22
# Motorola   Android         110  110      110     110           110        110
# Nokia      Android          46   46       46      46            46         46
#            Others           44   44       52      54            54         54
#            Windows          21   21       21      21            21         21
# OnePlus    Android          22   22       22      22            22         22
# Oppo       Android         129  129      129     129           129        129
# Others     Android         466  466      466     466           466        466
#            Others           34   34       34      34            34         34
#            Windows           9    9        9       9             9          9
# Panasonic  Android          47   47       47      47            47         47
# Realme     Android          41   41       41      41            41         41
# Samsung    Android         325  325      325     325           325        325
#            Others           36   36       36      36            36         36
#            Windows           3    3        3       3             3          3
# Sony       Android          88   88       88      88            88         88
# Spice      Android          30   30       30      30            30         30
# Vivo       Android         117  117      117     117           117        117
# XOLO       Android          47   47       47      41            47         47
#            Windows           2    2        2       1             2          2
# Xiaomi     Android         134  134      134     134           134        134
# ZTE        Android         141  141      141     141           141        141
#
#                     new_price  used_price
# brand_name os
# Acer       Android         48          48
#            Others           1           1
#            Windows          2           2
# Alcatel    Android        125         125
# Apple      iOS             59          59
# Asus       Android        126         126
# BlackBerry Android         22          22
# Celkon     Android         37          37
# Coolpad    Android         22          22
# Gionee     Android         56          56
# Google     Android         15          15
# HTC        Android        107         107
#            Windows          3           3
# Honor      Android        118         118
# Huawei     Android        255         255
#            Others           7           7
#            Windows          2           2
# Infinix    Android         10          10
# Karbonn    Android         30          30
# LG         Android        203         203
#            Others           9           9
# Lava       Android         35          35
#            Windows          1           1
# Lenovo     Android        172         172
# Meizu      Android         62          62
# Micromax   Android        107         107
#            Others          11          11
#            Windows          2           2
# Microsoft  Windows         22          22
# Motorola   Android        110         110
# Nokia      Android         46          46
#            Others          54          54
#            Windows         21          21
# OnePlus    Android         22          22
# Oppo       Android        129         129
# Others     Android        466         466
#            Others          34          34
#            Windows          9           9
# Panasonic  Android         47          47
# Realme     Android         41          41
# Samsung    Android        325         325
#            Others          36          36
#            Windows          3           3
# Sony       Android         88          88
# Spice      Android         30          30
# Vivo       Android        117         117
# XOLO       Android         47          47
#            Windows          2           2
# Xiaomi     Android        134         134
# ZTE        Android        141         141

# %% [markdown]
# #### 2) Outliers Treatment

# %%
print('0.75 percentile of used_price is' , df['used_price'].quantile(0.75))
print('0.85 percentile of used_price is' , df['used_price'].quantile(0.85))
print('0.90 percentile of used_price is' , df['used_price'].quantile(0.90))
print('0.91 percentile of used_price is' , df['used_price'].quantile(0.91))
print('0.92 percentile of used_price is' , df['used_price'].quantile(0.92))
print('0.93 percentile of used_price is' , df['used_price'].quantile(0.93))
print('0.94 percentile of used_price is' , df['used_price'].quantile(0.94))
print('0.95 percentile of used_price is' , df['used_price'].quantile(0.95))
print('0.96 percentile of used_price is' , df['used_price'].quantile(0.96))
print('0.97 percentile of used_price is' , df['used_price'].quantile(0.97))
print('0.98 percentile of used_price is' , df['used_price'].quantile(0.98))
# Out:
# 0.75 percentile of used_price is 126.0
# 0.85 percentile of used_price is 170.06
# 0.90 percentile of used_price is 209.6
# 0.91 percentile of used_price is 224.72800000000015
# 0.92 percentile of used_price is 248.44800000000004
# 0.93 percentile of used_price is 268.2350000000001
# 0.94 percentile of used_price is 291.6439999999997
# 0.95 percentile of used_price is 323.985
# 0.96 percentile of used_price is 359.9279999999997
# 0.97 percentile of used_price is 414.5930000000001
# 0.98 percentile of used_price is 485.39599999999916

# %% [markdown]
# Removed the high pricing phones which are greater than 800 .

# %%
df = df[(df['used_price'] < 600)]

# %% [markdown]
# #### 2) Map the null values with mean values

# %%
def replace_mean(column_name,brand_name,value):
        df[column_name][(df[column_name].isnull()) & (df['brand_name'] ==brand_name) ] = value
        print("Replaced the column null value ",column_name ," for the brand " ,brand_name ," With Value " ,value )

#df[(df['main_camera_mp'].isnull()) & (df['brand_name'] =='Acer') ]

# %%
df.isnull().sum()
# Out:
# brand_name            0
# os                    0
# screen_size           0
# 4g                    0
# 5g                    0
# main_camera_mp      172
# selfie_camera_mp      2
# int_memory           10
# ram                  10
# battery               6
# weight                7
# release_year          0
# days_used             0
# new_price             0
# used_price            0
# dtype: int64

# %% [markdown]
# #### Column : main_camera_mp null. value computation

# %% [markdown]
# The Infinix has all the records with main_camera_mp as null . Updaing the value with 16.0

# %%
df['main_camera_mp'][(df['main_camera_mp'].isnull()) & (df['brand_name'] =='Infinix') ] =16.0

# %% [markdown]
# the values are computed  based on the mean value

# %%
df.groupby('brand_name').agg({'main_camera_mp': lambda x: (x.isnull().sum(),x.mean())})
# Out:
#                       main_camera_mp
# brand_name
# Acer         (0, 6.9676470588235295)
# Alcatel       (0, 6.324799999999998)
# Apple         (0, 9.907407407407407)
# Asus         (3, 10.009426229508197)
# BlackBerry   (4, 10.333333333333334)
# Celkon        (0, 3.597297297297297)
# Coolpad      (3, 11.263157894736842)
# Gionee        (0, 9.913392857142856)
# Google        (0, 11.93333333333333)
# HTC          (0, 10.792727272727273)
# Honor        (0, 12.338983050847459)
# Huawei       (0, 10.318750000000003)
# Infinix                    (0, 16.0)
# Karbonn       (0, 6.796666666666668)
# LG            (0, 8.409808612440195)
# Lava          (2, 6.845588235294119)
# Lenovo         (0, 8.94622093023256)
# Meizu       (15, 13.608510638297876)
# Micromax     (0, 5.9737499999999955)
# Microsoft     (0, 9.454545454545455)
# Motorola    (16, 12.869565217391305)
# Nokia         (0, 5.576528925619835)
# OnePlus                   (17, 14.2)
# Oppo         (17, 10.46712962962963)
# Others        (0, 7.916168958742639)
# Panasonic    (2, 10.427777777777777)
# Realme                    (36, 13.0)
# Samsung        (0, 9.09817415730338)
# Sony         (5, 14.703703703703706)
# Spice         (0, 4.921666666666668)
# Vivo        (14, 12.859223300970873)
# XOLO         (0, 7.4551020408163255)
# Xiaomi      (24, 12.399082568807339)
# ZTE          (4, 11.705109489051097)

# %%
replace_mean('main_camera_mp','Asus',10) ## will replace for 4 records
replace_mean('main_camera_mp','BlackBerry',10) ## will replace for 4 records
replace_mean('main_camera_mp','Coolpad',12) ## will replace for 3 records
replace_mean('main_camera_mp','Lava',7) ## will replace for 2 records
replace_mean('main_camera_mp','Meizu',14) ## will replace for 15 records
replace_mean('main_camera_mp','Motorola',13) ## will replace for 16 records
replace_mean('main_camera_mp','OnePlus',14) ## will replace for 17 records
replace_mean('main_camera_mp','Oppo',10) ## will replace for 20 records
replace_mean('main_camera_mp','Panasonic',10) ## will replace for 2 records
replace_mean('main_camera_mp','Realme',13) ## will replace for 36 records
replace_mean('main_camera_mp','Sony',15) ## will replace for 36 records
replace_mean('main_camera_mp','Vivo',13) ## will replace for 14 records
replace_mean('main_camera_mp','Xiaomi',13) ## will replace for 24 records
replace_mean('main_camera_mp','ZTE',12) ## will replace for 4 records
# Out:
# Replaced the column null value  main_camera_mp  for the brand  Asus  With Value  10
# Replaced the column null value  main_camera_mp  for the brand  BlackBerry  With Value  10
# Replaced the column null value  main_camera_mp  for the brand  Coolpad  With Value  12
# Replaced the column null value  main_camera_mp  for the brand  Lava  With Value  7
# Replaced the column null value  main_camera_mp  for the brand  Meizu  With Value  14
# Replaced the column null value  main_camera_mp  for the brand  Motorola  With Value  13
# Replaced the column null value  main_camera_mp  for the brand  OnePlus  With Value  14
# Replaced the column null value  main_camera_mp  for the brand  Oppo  With Value  10
# Replaced the column null value  main_camera_mp  for the brand  Panasonic  With Value  10
# Replaced the column null value  main_camera_mp  for the brand  Realme  With Value  13
# Replaced the column null value  main_camera_mp  for the brand  Sony  With Value  15
# Replaced the column null value  main_camera_mp  for the brand  Vivo  With Value  13
# Replaced the column null value  main_camera_mp  for the brand  Xiaomi  With Value  13
# Replaced the column null value  main_camera_mp  for the brand  ZTE  With Value  12
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['main_camera_mp'].isnull().sum()
# Out:
# 0

# %%
df.groupby("brand_name").mean()
# Out:
#             screen_size  main_camera_mp  selfie_camera_mp  int_memory  \
# brand_name
# Acer          15.245490        6.967647          2.474510   23.215686
# Alcatel       13.128480        6.324800          2.260800   36.224000
# Apple         15.921111        9.907407          4.718519   74.370370
# Asus          15.433440       10.009200          4.377600   50.048000
# BlackBerry    12.410909       10.272727          5.140909   57.454545
# Celkon         9.554054        3.597297          0.635135  219.675676
# Coolpad       14.040000       11.363636          7.181818   36.363636
# Gionee        13.620536        9.913393          5.160714   43.714286
# Google        15.060000       11.933333          7.538462   57.600000
# HTC           12.966364       10.792727          5.740909   33.018182
# Honor         19.046102       12.338983         11.718644   74.644068
# Huawei        16.950430       10.318750         10.152344   67.687500
# Infinix       18.478000       16.000000         11.200000   38.400000
# Karbonn       11.683667        6.796667          1.823333   65.600333
# LG            13.656986        8.409809          5.095215   34.909091
# Lava          12.465278        6.854167          2.419444  104.000000
# Lenovo        16.110000        8.946221          5.158140   42.232558
# Meizu         15.221129       13.703226         10.629032   58.580645
# Micromax      12.176417        5.973750          2.271667   46.286667
# Microsoft     13.010000        9.454545          3.181818   31.272727
# Motorola      14.111389       12.888889          7.685185   48.444444
# Nokia         11.727355        5.576529          5.223140   46.487748
# OnePlus       20.810909       14.045455         14.272727  141.818182
# Oppo          15.553520       10.403600         14.638400   81.024000
# Others        13.907937        7.916169          4.001375   41.281071
# Panasonic     12.996170       10.409574          4.453191   27.914894
# Realme        17.655610       13.000000         11.365854   70.634146
# Samsung       14.453989        9.098174          5.732022   39.719101
# Sony          13.886744       14.720930          5.322093   31.255814
# Spice         11.746000        4.921667          1.573333   49.600000
# Vivo          19.031795       12.876068         14.412821   86.051282
# XOLO          12.482041        7.455102          1.718367   22.204082
# Xiaomi        18.894812       12.507519         11.961654   77.293233
# ZTE           13.984752       11.713475          6.373050   45.843972
#
#                  ram      battery      weight  release_year   days_used  \
# brand_name
# Acer        3.901961  2999.607843  225.872549   2014.372549  795.921569
# Alcatel     3.426000  2393.360000  166.465600   2014.976000  752.632000
# Apple       3.925926  3484.555556  219.953704   2016.407407  670.611111
# Asus        4.016000  3379.128000  215.135200   2015.344000  749.960000
# BlackBerry  3.829545  2822.500000  160.568182   2015.181818  692.909091
# Celkon      1.466216  1459.459459  135.202703   2013.243243  801.405405
# Coolpad     3.954545  2945.000000  154.381818   2016.363636  766.227273
# Gionee      3.933036  3117.946429  161.476786   2014.928571  782.642857
# Google      4.533333  3628.333333  187.733333   2017.933333  519.200000
# HTC         4.000000  2614.454545  155.247273   2015.172727  756.818182
# Honor       4.593220  3635.677966  177.488136   2018.161017  465.601695
# Huawei      4.536367  3559.152344  198.514453   2017.101562  565.269531
# Infinix     2.600000  4800.000000  184.400000   2019.600000  313.300000
# Karbonn     3.375000  1730.000000  137.933333   2013.366667  820.066667
# LG          3.854067  2894.162679  164.683493   2015.866029  673.368421
# Lava        3.277778  2248.611111  140.408333   2014.527778  787.222222
# Lenovo      3.886628  3653.255814  227.841279   2015.610465  724.767442
# Meizu       4.451613  3368.220339  160.790323   2017.177419  657.032258
# Micromax    3.750000  2225.416667  145.315000   2014.300000  816.508333
# Microsoft   4.000000  2382.380952  172.795455   2014.863636  853.636364
# Motorola    3.796296  3170.879630  164.042593   2017.055556  563.296296
# Nokia       3.601351  2132.689076  136.552893   2016.330579  621.338843
# OnePlus     6.363636  3716.590909  181.318182   2018.000000  513.000000
# Oppo        4.800000  3354.480000  165.398000   2017.224000  563.176000
# Others      3.751041  2806.758350  189.854224   2015.166994  740.153242
# Panasonic   4.000000  2682.978723  149.103191   2015.574468  810.468085
# Realme      4.195122  4337.317073  188.804878   2019.463415  313.390244
# Samsung     4.061798  3199.373596  192.858427   2015.620787  710.620787
# Sony        4.023256  2925.639535  178.184884   2015.244186  740.441860
# Spice       3.750000  2191.000000  161.130000   2013.233333  881.233333
# Vivo        4.756410  3718.846154  172.914103   2017.880342  500.598291
# XOLO        4.000000  2220.000000  151.019048   2013.653061  823.244898
# Xiaomi      4.511278  3926.917293  183.282707   2017.661654  540.849624
# ZTE         4.023050  2877.836879  156.437943   2015.907801  726.297872
#
#              new_price  used_price
# brand_name
# Acer        172.867647   63.798431
# Alcatel     142.499092   55.326080
# Apple       587.042806  256.463889
# Asus        243.697556   98.539120
# BlackBerry  234.774545  102.039091
# Celkon       60.956486   22.648378
# Coolpad     194.285455   77.928182
# Gionee      255.379286   91.881964
# Google      474.716667  239.211333
# HTC         249.853818   99.626000
# Honor       235.897915  132.285932
# Huawei      274.627125  142.083281
# Infinix     106.017000   68.979000
# Karbonn     110.384333   38.069333
# LG          231.715833  108.004545
# Lava        107.424722   40.112778
# Lenovo      193.358779   77.147500
# Meizu       269.569242  126.515484
# Micromax    106.964667   38.134417
# Microsoft   166.366818   55.316818
# Motorola    191.120287   93.066759
# Nokia       130.600802   59.393719
# OnePlus     558.230818  318.515909
# Oppo        324.259804  165.254000
# Others      191.112094   78.492102
# Panasonic   171.426596   60.302979
# Realme      186.031415  124.169024
# Samsung     274.394624  118.414719
# Sony        264.873506  106.988837
# Spice        98.000000   32.299667
# Vivo        320.268355  168.190855
# XOLO        130.898571   47.340204
# Xiaomi      240.477447  129.107820
# ZTE         216.800922   93.621489

# %% [markdown]
# #### selfie_camera_mp null value computation

# %%
df['selfie_camera_mp'].isnull().sum()
# Out:
# 2

# %%
df[df['selfie_camera_mp'].isnull()]
# Out:
#      brand_name       os  screen_size   4g  5g  main_camera_mp  \
# 1131     Google  Android        15.72  yes  no            12.2
# 1132     Google  Android        13.49  yes  no            12.2
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 1131               NaN        64.0  4.0   3430.0   184.0          2018
# 1132               NaN        64.0  4.0   2915.0   148.0          2018
#
#       days_used  new_price  used_price
# 1131        475     959.08      479.52
# 1132        424     849.87      425.16

# %%
df['selfie_camera_mp'][(df['selfie_camera_mp'].isnull()) ] =12.2

# %% [markdown]
# #### int_memory & ram  null value computation

# %%
df['int_memory'].isnull().sum()
# Out:
# 10

# %%
df[(df['int_memory'].isnull())]
# Out:
#      brand_name      os  screen_size  4g  5g  main_camera_mp  \
# 2140      Nokia  Others         5.72  no  no             0.3
# 2141      Nokia  Others         5.72  no  no             0.3
# 2142      Nokia  Others         6.35  no  no             2.0
# 2143      Nokia  Others         6.35  no  no             2.0
# 2144      Nokia  Others         5.72  no  no             2.0
# 2145      Nokia  Others         5.72  no  no             2.0
# 2146      Nokia  Others         3.18  no  no             2.0
# 2147      Nokia  Others         3.18  no  no             2.0
# 2148      Nokia  Others         5.72  no  no             0.3
# 2149      Nokia  Others         5.72  no  no             0.3
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 2140               0.3         NaN  NaN      NaN    81.0          2016
# 2141               0.3         NaN  NaN      NaN    82.6          2016
# 2142               2.0         NaN  NaN   1200.0    91.8          2015
# 2143               2.0         NaN  NaN   1200.0    91.8          2015
# 2144               2.0         NaN  NaN   1100.0    79.0          2015
# 2145               2.0         NaN  NaN   1100.0    79.0          2015
# 2146               2.0         NaN  NaN    800.0    69.6          2015
# 2147               2.0         NaN  NaN    800.0    69.8          2015
# 2148               2.0         NaN  NaN   1100.0    78.4          2015
# 2149               2.0         NaN  NaN   1100.0    78.6          2015
#
#       days_used  new_price  used_price
# 2140        815      29.21        8.65
# 2141       1023      38.78       11.42
# 2142        867      68.01       20.46
# 2143        772      69.94       28.06
# 2144       1012      41.92       12.52
# 2145        798      40.48       16.13
# 2146       1009      19.92        6.07
# 2147        665      18.48        7.48
# 2148        559      29.33       14.76
# 2149        682      30.00       12.03

# %%
replace_mean('int_memory','Nokia',46.487748) ## will replace for 10 records 46.487748
replace_mean('ram','Nokia',3.601351) ## will replace for 10 records 46.487748
# Out:
# Replaced the column null value  int_memory  for the brand  Nokia  With Value  46.487748
# Replaced the column null value  ram  for the brand  Nokia  With Value  3.601351

# %%
df['int_memory'].isnull().sum()
# Out:
# 0

# %%
df['ram'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Computation the null values for battery

# %%
df[(df['battery'].isnull())]
# Out:
#      brand_name       os  screen_size   4g  5g  main_camera_mp  \
# 1901      Meizu  Android        13.49  yes  no            13.0
# 1903      Meizu  Android        13.49  yes  no            20.7
# 1904      Meizu  Android        18.42  yes  no            20.7
# 2037  Microsoft  Windows        26.35   no  no             5.0
# 2140      Nokia   Others         5.72   no  no             0.3
# 2141      Nokia   Others         5.72   no  no             0.3
#
#       selfie_camera_mp  int_memory       ram  battery  weight  release_year  \
# 1901               5.0   16.000000  4.000000      NaN   145.0          2014
# 1903               5.0   16.000000  4.000000      NaN   158.0          2014
# 1904               2.0   16.000000  4.000000      NaN   147.0          2014
# 2037               3.5   32.000000  4.000000      NaN   675.9          2013
# 2140               0.3   46.487748  3.601351      NaN    81.0          2016
# 2141               0.3   46.487748  3.601351      NaN    82.6          2016
#
#       days_used  new_price  used_price
# 1901        986     129.49       38.67
# 1903       1043     399.67      119.86
# 1904       1007     339.04      101.65
# 2037        931     331.21       99.49
# 2140        815      29.21        8.65
# 2141       1023      38.78       11.42

# %%
replace_mean('battery','Meizu',3368.220339) ## will replace for 3 records 
replace_mean('battery','Microsoft',2382.380952) ## will replace for 1 records 
replace_mean('battery','Nokia',2132.689076) ## will replace for 2 records
# Out:
# Replaced the column null value  battery  for the brand  Meizu  With Value  3368.220339
# Replaced the column null value  battery  for the brand  Microsoft  With Value  2382.380952
# Replaced the column null value  battery  for the brand  Nokia  With Value  2132.689076
# /Users/sathya/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['battery'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Computation the null values for weight

# %%
df[(df['weight'].isnull())]
# Out:
#      brand_name       os  screen_size   4g  5g  main_camera_mp  \
# 3113       XOLO  Android        12.70  yes  no            13.0
# 3114       XOLO  Android        13.49  yes  no             8.0
# 3115       XOLO  Android        12.70   no  no             8.0
# 3116       XOLO  Android        10.95   no  no             5.0
# 3117       XOLO  Android        12.70   no  no             5.0
# 3118       XOLO  Windows        12.70   no  no             8.0
# 3119       XOLO  Android        12.70   no  no             8.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 3113               5.0        32.0  4.0   2400.0     NaN          2015
# 3114               5.0        16.0  4.0   3200.0     NaN          2015
# 3115               2.0        32.0  4.0   2100.0     NaN          2015
# 3116               0.3        32.0  4.0   1800.0     NaN          2015
# 3117               0.3        16.0  4.0   2500.0     NaN          2015
# 3118               2.0        32.0  4.0   2200.0     NaN          2015
# 3119               5.0        32.0  4.0   2500.0     NaN          2015
#
#       days_used  new_price  used_price
# 3113        576     138.44       69.38
# 3114        800     179.33       53.81
# 3115        878      59.21       17.77
# 3116       1036      81.13       24.32
# 3117        679      77.26       30.85
# 3118        838     120.51       36.14
# 3119       1045     119.75       35.78

# %%
replace_mean('weight','XOLO',151.019048) ## will replace for 3 records
# Out:
# Replaced the column null value  weight  for the brand  XOLO  With Value  151.019048

# %%
df.columns
# Out:
# Index(['brand_name', 'os', 'screen_size', '4g', '5g', 'main_camera_mp',
#        'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'new_price', 'used_price'],
#       dtype='object')

# %% [markdown]
# ### computing the value of brand "Others" based on the features

# %%
df=df[(df['brand_name'] != 'Others' )]

# %%
df.shape
# Out:
# (3028, 15)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Convert the categorical Columns into the Numerical COlumns

# %%
df["4g"]=df["4g"].map(dict(yes=1, no=0))
df["5g"]=df["5g"].map(dict(yes=1, no=0))

# %%
dummy=pd.get_dummies(df["os"])
df=df.merge(dummy,left_index=True,right_index=True)

dummy=pd.get_dummies(df["brand_name"])
df=df.merge(dummy,left_index=True,right_index=True)

# %% [markdown]
# ## Building a Linear Regression model

# %% [markdown]
# Defining X and Y , X  is the dependant variable for computing the Yvalue ( Here it is used_price)

# %%
X = df[[ 'screen_size', '4g', '5g', 'main_camera_mp',
       'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight',
       'release_year', 'days_used', 'new_price', 'Android',
        'Windows', 'iOS', 'Acer', 'Alcatel', 'Apple', 'Asus',
       'BlackBerry', 'Celkon', 'Coolpad', 'Gionee', 'Google', 'HTC', 'Honor',
       'Huawei', 'Infinix', 'Karbonn', 'LG', 'Lava', 'Lenovo', 'Meizu',
       'Micromax', 'Microsoft', 'Motorola', 'Nokia', 'OnePlus', 'Oppo',
        'Panasonic', 'Realme', 'Samsung', 'Sony', 'Spice', 'Vivo',
       'XOLO', 'Xiaomi', 'ZTE']]
# the dependent variable
y = df[['used_price']]

# %% [markdown]
# #### Train and test Split for evalauvating & training the model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# Building the Simple Linear Regression Model with taining data set

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Printing the co-efficients for each features in the model

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for screen_size is -0.16732354231814284
# The coefficient for 4g is -8.062206776644423
# The coefficient for 5g is 52.184764912759434
# The coefficient for main_camera_mp is -1.1497696621743962
# The coefficient for selfie_camera_mp is 0.15821520014849122
# The coefficient for int_memory is 0.029102126457684604
# The coefficient for ram is 3.505657283983864
# The coefficient for battery is 0.000954045838057041
# The coefficient for weight is -0.02454771263512369
# The coefficient for release_year is 2.6536944408136156
# The coefficient for days_used is -0.1064790610125608
# The coefficient for new_price is 0.4723702360050635
# The coefficient for Android is 5.304385644825929
# The coefficient for Windows is 6.307963633746932
# The coefficient for iOS is 1.544318108139394
# The coefficient for Acer is 1.1932308407040277
# The coefficient for Alcatel is 3.3916895689439346
# The coefficient for Apple is 1.544318108139394
# The coefficient for Asus is -0.3119110197794564
# The coefficient for BlackBerry is 0.6061408739198947
# The coefficient for Celkon is 8.389110381498183
# The coefficient for Coolpad is -0.2996635022537143
# The coefficient for Gionee is -8.992630298576195
# The coefficient for Google is -2.900136793551783
# The coefficient for HTC is 0.3367786578575759
# The coefficient for Honor is -8.237657695502566
# The coefficient for Huawei is -2.0078173490408555
# The coefficient for Infinix is -8.25383756055645
# The coefficient for Karbonn is 6.095156505987605
# The coefficient for LG is 3.000182070060916
# The coefficient for Lava is 3.4073942029422253
# The coefficient for Lenovo is -2.1292452730724842
# The coefficient for Meizu is 0.23746736440452004
# The coefficient for Micromax is 4.091429415868172
# The coefficient for Microsoft is 1.3271007846023128
# The coefficient for Motorola is 0.12749097934191872
# The coefficient for Nokia is -8.26644033590267
# The coefficient for OnePlus is 13.596441384603036
# The coefficient for Oppo is -8.603351452394795
# The coefficient for Panasonic is 1.6968904277616772
# The coefficient for Realme is -15.415790862460886
# The coefficient for Samsung is -0.9808490669552038
# The coefficient for Sony is 3.2502865026657095
# The coefficient for Spice is 11.97908879253903
# The coefficient for Vivo is -6.279728996268501
# The coefficient for XOLO is 6.374209325090203
# The coefficient for Xiaomi is -2.0159872380748607
# The coefficient for ZTE is 4.0506412574595485

# %%
intercept = regression_model.intercept_[0]
print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -5284.549151058024

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.9461408415606484

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.9414386655259884

# %%
y_predict = regression_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math

mse = mean_squared_error(y_test, y_predict)

rmse = math.sqrt(mse)

print(rmse)
# Out:
# 21.356044737627357

# %%
r2 = r2_score(y_test, y_predict)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.9414386655259884

# %% [markdown]
# Though the R2 valueis 0.94 , the RMSE is 22.82 . The lesser the RMSE the grater the efficiency ofthe model , so we will try to reduce the RMSE by doing some feature selection

# %% [markdown]
# Scatter plot between the predicted valueand actual value

# %%
x=np.arange(0,len(X_test),1)
fig, ax = plt.subplots(figsize=(12, 8)) 
 
plt.title('Actual Versus predictions', fontsize=12)
s1=plt.scatter(x, y_test,color='red')
s2=plt.scatter(x, y_predict, color='blue')
# produce a legend with the unique colors from the scatter
plt.legend([s1,s2],['Actual','Predicted'])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Find the Co-relation with used_price for all the features

# %%
df_columns = df.drop(['used_price'], axis=1)
df_used_price = df['used_price']

# %%
df_corr= df_columns.corrwith(df_used_price)
df_corr.sort_values(inplace=True)
df_corr.index

df_columns.corrwith(df_used_price)

fig, ax = plt.subplots(figsize=(18, 10))  
objects = df_corr.index
y_pos = np.arange(len(objects))
# this does not work 
# correlation = [corr_open, corr_high, corr_low, corr_close, corr_volume]

plt.barh(df_corr.index, df_corr, align='center', alpha=0.5)
plt.ylabel('Correlation', fontsize=11)
plt.yticks(size = 9)
plt.title('Correlations with used_price ', fontsize=12)

plt.show()

# %%
df_corr

# %% [markdown]
# ## Feature Engineering

# %%
df_corr = df [[ '4g', '5g',
       'selfie_camera_mp', 'int_memory', 'ram', 'battery',
        'days_used', 'new_price', 'Android','release_year',
      'iOS', 'Acer', 'Alcatel',
        'Celkon',   'Gionee', 'Honor',
       'Huawei', 'Infinix', 'Karbonn', 'LG', 'Lava', 'Lenovo', 'Meizu',
       'Micromax', 'Motorola', 'Nokia', 'OnePlus', 'Oppo',
         'Panasonic', 'Realme', 'Samsung', 'Spice', 'Vivo',
       'XOLO', 'Xiaomi', 'ZTE' ]]

# %%
corr = df_corr.corr()
fig, ax = plt.subplots(figsize=(18, 10)) 
sns.heatmap(corr,annot=True)

# %%
X = df.drop(columns =['used_price','brand_name','os'])
y = df['used_price']
fig, ax = plt.subplots(figsize=(10, 8)) 
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
plt.title('Top 20 Features based on ExtraTreesRegressor ', fontsize=12)
#print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
X = df[['4g', '5g',
       'selfie_camera_mp', 'int_memory', 'ram', 'battery',
        'days_used', 'new_price', 'Android','release_year',
      'iOS', 'Acer', 'Alcatel',
        'Celkon',   'Gionee', 'Honor',
       'Huawei', 'Infinix', 'Karbonn', 'LG', 'Lava', 'Lenovo', 'Meizu',
       'Micromax', 'Motorola', 'Nokia', 'OnePlus', 'Oppo',
        'Panasonic', 'Realme', 'Samsung', 'Spice', 'Vivo',
       'XOLO', 'Xiaomi', 'ZTE' ]]
# the dependent variable
y = df[['used_price']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform (X_test)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error
import math

mse = mean_squared_error(y_test, y_predict)

rmse = math.sqrt(mse)

print(rmse)
# Out:
# 134.57874248038343

# %%
r2 = r2_score(y_test, y_predict)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is -1.3255316392892627

# %%
x=np.arange(0,len(X_test),1)
fig, ax = plt.subplots(figsize=(12, 8)) 
 
plt.title('Actual Versus predictions', fontsize=12)
s1=plt.scatter(x, y_test,color='red')
s2=plt.scatter(x, y_predict, color='blue')
# produce a legend with the unique colors from the scatter
plt.legend([s1,s2],['Actual','Predicted'])
ax.grid(True)
plt.show()

# %% [markdown]
# ## Final Model Summary

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):

    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)

    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
regression_results(y_test, y_predict)
# Out:
# explained_variance:  0.0034
# mean_squared_log_error:  18.0384
# r2:  -1.3255
# MAE:  101.7327
# MSE:  18111.4379
# RMSE:  134.5787

# %% [markdown]
# ## Actionable Insights and Recommendations
#
# -
